# %%
import numpy as np 
import tensorflow as tf 
from tensorflow.keras.datasets import imdb 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Dense 
from tensorflow.keras.preprocessing.sequence import pad_sequences 
import matplotlib.pyplot as plt

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000) 
max_len = 200 
X_train = pad_sequences(X_train, maxlen=max_len) 
X_test  = pad_sequences(X_test,  maxlen=max_len)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
def build_vanilla_rnn(): 
    model = Sequential([ 
        Embedding(input_dim=10000, output_dim=32, input_length=200), 
        SimpleRNN(32), 
        Dense(1, activation='sigmoid') 
    ]) 
    model.compile(loss='binary_crossentropy', 
                  optimizer='adam', metrics=['accuracy']) 
    return model

# %%
rnn_model = build_vanilla_rnn() 
rnn_history = rnn_model.fit(X_train, y_train, epochs=5, 
                            batch_size=64, validation_split=0.2) 
rnn_loss, rnn_acc = rnn_model.evaluate(X_test, y_test) 
print(f'Vanilla RNN Test Accuracy: {rnn_acc:.4f}')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/5
# c:\Users\kumbh\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:103: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.6332 - loss: 0.6263 - val_accuracy: 0.7228 - val_loss: 0.5476
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7448 - loss: 0.5196 - val_accuracy: 0.6998 - val_loss: 0.5695
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8848 - loss: 0.2987 - val_accuracy: 0.7706 - val_loss: 0.5092
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9690 - loss: 0.1071 - val_accuracy: 0.7794 - val_loss: 0.5747
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9950 - loss: 0.0298 - val_accuracy: 0.7894 - val_loss: 0.6517
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7953 - loss: 0.6224
# Vanilla RNN Test Accuracy: 0.7953

# %%
def build_lstm(): 
    model = Sequential([ 
        Embedding(input_dim=10000, output_dim=32, input_length=200), 
        LSTM(32), 
        Dense(1, activation='sigmoid') 
    ]) 
    model.compile(loss='binary_crossentropy', 
                  optimizer='adam', metrics=['accuracy']) 
    return model

# %%
lstm_model = build_lstm() 
lstm_history = lstm_model.fit(X_train, y_train, epochs=5, 
                              batch_size=64, validation_split=0.2) 
lstm_loss, lstm_acc = lstm_model.evaluate(X_test, y_test) 
print(f'LSTM Test Accuracy: {lstm_acc:.4f}')
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.7778 - loss: 0.4585 - val_accuracy: 0.8514 - val_loss: 0.3493
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.8996 - loss: 0.2548 - val_accuracy: 0.8756 - val_loss: 0.3083
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.9226 - loss: 0.2049 - val_accuracy: 0.8652 - val_loss: 0.3188
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.9442 - loss: 0.1555 - val_accuracy: 0.8704 - val_loss: 0.3414
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.9545 - loss: 0.1269 - val_accuracy: 0.8708 - val_loss: 0.3779
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8619 - loss: 0.4047
# LSTM Test Accuracy: 0.8619

# %%
def build_gru(): 
    model = Sequential([ 
        Embedding(input_dim=10000, output_dim=32, input_length=200), 
        GRU(32), 
        Dense(1, activation='sigmoid') 
    ]) 
    model.compile(loss='binary_crossentropy', 
                  optimizer='adam', metrics=['accuracy']) 
    return model

# %%
 
gru_model = build_gru() 
gru_history = gru_model.fit(X_train, y_train, epochs=5, 
                            batch_size=64, validation_split=0.2) 
gru_loss, gru_acc = gru_model.evaluate(X_test, y_test) 
print(f'GRU Test Accuracy: {gru_acc:.4f}')
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - accuracy: 0.7667 - loss: 0.4662 - val_accuracy: 0.8528 - val_loss: 0.3441
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.8865 - loss: 0.2797 - val_accuracy: 0.8704 - val_loss: 0.3304
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9201 - loss: 0.2129 - val_accuracy: 0.8636 - val_loss: 0.3455
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9372 - loss: 0.1736 - val_accuracy: 0.8610 - val_loss: 0.3965
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 57ms/step - accuracy: 0.9495 - loss: 0.1419 - val_accuracy: 0.8638 - val_loss: 0.3867
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8498 - loss: 0.4114
# GRU Test Accuracy: 0.8498

# %%
plt.figure(figsize=(14, 5)) 
 
plt.subplot(1, 2, 1) 
plt.plot(rnn_history.history['val_accuracy'],  label='Vanilla RNN') 
plt.plot(lstm_history.history['val_accuracy'], label='LSTM') 
plt.plot(gru_history.history['val_accuracy'],  label='GRU') 
plt.title('Validation Accuracy Comparison') 
plt.xlabel('Epoch'); plt.ylabel('Accuracy') 
plt.legend() 
 
plt.subplot(1, 2, 2) 
plt.plot(rnn_history.history['val_loss'],  label='Vanilla RNN') 
plt.plot(lstm_history.history['val_loss'], label='LSTM') 
plt.plot(gru_history.history['val_loss'],  label='GRU') 
plt.title('Validation Loss Comparison') 
plt.xlabel('Epoch'); plt.ylabel('Loss') 
plt.legend() 
 
plt.tight_layout() 
plt.savefig('rnn_comparison.png', dpi=150) 
plt.show()
