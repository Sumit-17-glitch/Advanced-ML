# %%
import torch
import torchvision
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

# %config InlineBackend.figure_format = 'svg' 
plt.style.use('seaborn-v0_8-darkgrid')

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

    except RuntimeError as e:
        print(e)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
ratings_data = pd.read_csv('C:\\College work\\Advanced ML\\exp 5\\ratings.csv')
movie_names_data = pd.read_csv('C:\\College work\\Advanced ML\\exp 5\\movies.csv')
print("Data loaded successfully!")
print(f"Ratings shape: {ratings_data.shape}")
print(f"Movies shape: {movie_names_data.shape}")
# Out:
# Data loaded successfully!
# Ratings shape: (100836, 4)
# Movies shape: (9742, 3)

# %%
n_movies = len(movie_names_data)
n_user = len(ratings_data['userId'].unique())
print(f"Number of movies: {n_movies}")
print(f"Number of users: {n_user}")
# Out:
# Number of movies: 9742
# Number of users: 610

# %%
ratings_data = pd.merge(ratings_data, movie_names_data, on='movieId', how='inner')
ratings_data.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
from sklearn.preprocessing import LabelEncoder
import random
Y = ratings_data.rating
user_enc = LabelEncoder()
movie_enc = LabelEncoder()
X = np.array([user_enc.fit_transform(ratings_data.userId),
              movie_enc.fit_transform(ratings_data.title)]).T

# %%
print("Y ", Y[:5])
print("X ", X[:5])
# Out:
# Y  0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: rating, dtype: float64
# X  [[   0 8871]
#  [   0 3661]
#  [   0 3845]
#  [   0 7523]
#  [   0 9119]]

# %%
user_enc.classes_[5], movie_enc.classes_[3661]
# Out:
# (np.int64(6), 'Grumpier Old Men (1995)')

# %%
for x, y in zip(X[:10], Y[:10]):
    print(f"X: {list(x)}, Y: {y}")
# Out:
# X: [np.int64(0), np.int64(8871)], Y: 4.0
# X: [np.int64(0), np.int64(3661)], Y: 4.0
# X: [np.int64(0), np.int64(3845)], Y: 4.0
# X: [np.int64(0), np.int64(7523)], Y: 5.0
# X: [np.int64(0), np.int64(9119)], Y: 5.0
# X: [np.int64(0), np.int64(3252)], Y: 3.0
# X: [np.int64(0), np.int64(1284)], Y: 5.0
# X: [np.int64(0), np.int64(1337)], Y: 4.0
# X: [np.int64(0), np.int64(7180)], Y: 5.0
# X: [np.int64(0), np.int64(1535)], Y: 5.0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
num_users = len(X)
num_movies = len(X)

# %%
from keras.layers import Input, Embedding, Flatten, Dot, Dense, Activation, Dropout
from keras.models import Model

def build_model():
    movie_input = Input(shape=[1], name="Book-Input")
    movie_embedding = Embedding(n_movies+1, 15, name="Book-Embedding")(movie_input)
    movie_vec = Flatten(name="Flatten-Books")(movie_embedding)

    user_input = Input(shape=[1], name="User-Input")
    user_embedding = Embedding(n_user+1, 15, name="User-Embedding")(user_input)
    user_vec = Flatten(name="Flatten-Users")(user_embedding)
    
    prod = Dot(name="Dot-Product", axes=1)([user_vec, movie_vec])
    
    prod = Dense(32)(prod)
    prod = Activation('relu')(prod)
    prod = Dropout(0.5)(prod)

    prod = Dense(16)(prod)
    prod = Activation('relu')(prod)
    prod = Dropout(0.5)(prod)
    prod = Dense(1)(prod)


    model = Model([user_input, movie_input], prod)
    model.compile('adam', 'mean_squared_error', metrics=['accuracy'])

    return model


model = build_model()

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='./checkpoint.weights.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1)

history = model.fit([X_train[:, 0], X_train[:, 1]], Y_train, 
            epochs=15, 
            verbose=1,
            batch_size=64, 
            validation_data=([X_test[:, 0], X_test[:, 1]], Y_test), 
            callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/15
# 1244/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0218 - loss: 5.2230
# Epoch 1: val_loss improved from None to 1.21167, saving model to ./checkpoint.weights.h5
#
# Epoch 1: finished saving model to ./checkpoint.weights.h5
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0264 - loss: 3.2346 - val_accuracy: 0.0280 - val_loss: 1.2117
# Epoch 2/15
# 1244/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0275 - loss: 1.9936
# Epoch 2: val_loss improved from 1.21167 to 1.16842, saving model to ./checkpoint.weights.h5
#
# Epoch 2: finished saving model to ./checkpoint.weights.h5
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0279 - loss: 1.8915 - val_accuracy: 0.0280 - val_loss: 1.1684
# Epoch 3/15
# 1260/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0289 - loss: 1.5985
# Epoch 3: val_loss improved from 1.16842 to 1.04168, saving model to ./checkpoint.weights.h5
#
# Epoch 3: finished saving model to ./checkpoint.weights.h5
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0279 - loss: 1.5089 - val_accuracy: 0.0280 - val_loss: 1.0417
# Epoch 4/15
# 1259/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0274 - loss: 1.1126
# Epoch 4: val_loss improved from 1.04168 to 0.91032, saving model to ./checkpoint.weights.h5
#
# Epoch 4: finished saving model to ./checkpoint.weights.h5
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0279 - loss: 1.0410 - val_accuracy: 0.0280 - val_loss: 0.9103
# Epoch 5/15
# 1237/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0290 - loss: 0.7468
# Epoch 5: val_loss improved from 0.91032 to 0.89363, saving model to ./checkpoint.weights.h5
#
# Epoch 5: finished saving model to ./checkpoint.weights.h5
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0278 - loss: 0.7252 - val_accuracy: 0.0280 - val_loss: 0.8936
# Epoch 6/15
# 1257/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0277 - loss: 0.5755
# Epoch 6: val_loss improved from 0.89363 to 0.88652, saving model to ./checkpoint.weights.h5
#
# Epoch 6: finished saving model to ./checkpoint.weights.h5
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0276 - loss: 0.5771 - val_accuracy: 0.0280 - val_loss: 0.8865
# Epoch 7/15
# 1238/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0259 - loss: 0.5033
# Epoch 7: val_loss did not improve from 0.88652
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0271 - loss: 0.5116 - val_accuracy: 0.0280 - val_loss: 0.9005
# Epoch 8/15
# 1258/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0260 - loss: 0.4608
# Epoch 8: val_loss did not improve from 0.88652
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0268 - loss: 0.4761 - val_accuracy: 0.0280 - val_loss: 0.9145
# Epoch 9/15
# 1257/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0257 - loss: 0.4394
# Epoch 9: val_loss did not improve from 0.88652
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0265 - loss: 0.4546 - val_accuracy: 0.0280 - val_loss: 0.9278
# Epoch 10/15
# 1240/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0259 - loss: 0.4214
# Epoch 10: val_loss did not improve from 0.88652
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0263 - loss: 0.4364 - val_accuracy: 0.0279 - val_loss: 0.9316
# Epoch 11/15
# 1257/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0256 - loss: 0.4146
# Epoch 11: val_loss did not improve from 0.88652
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0259 - loss: 0.4232 - val_accuracy: 0.0279 - val_loss: 0.9321
# Epoch 12/15
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0271 - loss: 0.4072
# Epoch 12: val_loss did not improve from 0.88652
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0262 - loss: 0.4157 - val_accuracy: 0.0279 - val_loss: 0.9448
# Epoch 13/15
# 1239/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0262 - loss: 0.3928
# Epoch 13: val_loss did not improve from 0.88652
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0260 - loss: 0.4048 - val_accuracy: 0.0280 - val_loss: 0.9439
# Epoch 14/15
# 1251/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0255 - loss: 0.3838
# Epoch 14: val_loss did not improve from 0.88652
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0259 - loss: 0.3968 - val_accuracy: 0.0280 - val_loss: 0.9580
# Epoch 15/15
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0261 - loss: 0.3851
# Epoch 15: val_loss did not improve from 0.88652
# 1261/1261 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.0262 - loss: 0.3922 - val_accuracy: 0.0280 - val_loss: 0.9605

# %%
X_test[:5], Y_test[:5]
# Out:
# (array([[ 275, 4337],
#         [ 598, 7425],
#         [ 482,  334],
#         [ 201, 3548],
#         [ 273, 3540]]),
#  41008    5.0
#  94274    2.5
#  77380    2.5
#  29744    3.0
#  40462    4.0
#  Name: rating, dtype: float64)

# %%
predictions = model.predict([X_test[:5, 0], X_test[:5, 1]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step

# %%
print(predictions,"\n\n", Y_test[:5].values)
# Out:
# [[4.160441 ]
#  [3.5902853]
#  [2.8637896]
#  [4.144992 ]
#  [3.1654177]]
#
#  [5.  2.5 2.5 3.  4. ]

# %%
movie_enc.classes_[4]
# Out:
# "'Til There Was You (1997)"

# %%
def extract_true_ratings(user_id, X_test):
    
    true_ratings = list()
    for x, y in X_test:
        if x == user_id:
            rating = ratings_data[(ratings_data['userId'] == user_enc.classes_[user_id]) \
                & (ratings_data['title'] == movie_enc.classes_[y])]['rating'].values[0]
            true_ratings.append(rating)

    return true_ratings

# %%
test_user_id = 5  
extract_true_ratings(test_user_id, X_test)
# Out:
# [np.float64(4.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(2.0),
#  np.float64(5.0),
#  np.float64(4.0),
#  np.float64(4.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(2.0),
#  np.float64(5.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(5.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(5.0),
#  np.float64(4.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(4.0),
#  np.float64(1.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(4.0),
#  np.float64(4.0),
#  np.float64(4.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(4.0),
#  np.float64(4.0),
#  np.float64(3.0),
#  np.float64(5.0),
#  np.float64(4.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(4.0),
#  np.float64(5.0)]

# %%
def predict_ratings(user_id, X_test):
    '''
    given user id predict all ratings for movies
    '''
    user_data = ratings_data[ratings_data['userId'] == user_id]
    movie_ids, movie_names, predictions, movie_genres = list(), list(), list(), list()
    i = 0
    for _id, movie_id in X_test:
        if user_id == X_test[i][0]:
            movie_ids.append(X_test[i, 1])
            movie_names.append(movie_enc.classes_[movie_id])
            pred = model.predict([ np.array([X_test[i, 0]]), np.array([X_test[i, 1]]) ])
            predictions.append(pred[0][0])
        i += 1
    return movie_ids, movie_names, movie_genres, predictions

# %%
test_user_id = 7
userid_rating_data = ratings_data[ratings_data['userId'] == test_user_id]

# %%
movie_ids, movie_names, movie_genres, predictions = predict_ratings(test_user_id, X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
dictionary = {"user_id": [test_user_id]*len(movie_ids),
              "movie_id": movie_ids,
              "movie_name":movie_names,
              "predicted_ratings":predictions,
              "true_ratings": extract_true_ratings(test_user_id, X_test) 
              }

# %%
prediction_dataframe = pd.DataFrame.from_dict(dictionary, orient='index').transpose()
prediction_dataframe.sort_values('predicted_ratings', ascending=False)
# Out:
#   user_id movie_id                                         movie_name  \
# 0       7     6865                                Pulp Fiction (1994)
# 2       7     7912                                       Speed (1994)
# 1       7     7755                        Sleepless in Seattle (1993)
# 5       7     7421                            Schindler's List (1993)
# 3       7     1799  City Slickers II: The Legend of Curly's Gold (...
# 4       7     2139                          Dances with Wolves (1990)
#
#   predicted_ratings true_ratings
# 0          4.071905          4.0
# 2          3.809663          4.0
# 1          3.769693          3.0
# 5          3.684962          5.0
# 3          3.160363          1.0
# 4          2.455306          5.0
